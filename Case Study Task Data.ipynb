# %% [markdown]
# # Data in format for GA
# Job number: (task ID, machine ID, duration, energy consumption (kWh))

# %%
jobs_data = {
    "Job1": [("A", 8, 2, 26), ("B", 6, 2, 21), ("C", 10, 2, 24), ("D", 1, 1, 10), ("E", 11, 3, 20), ("F", 5, 4, 16), ("G", 2, 1, 20), ("H", 4, 1, 12), ("I", 3, 1, 23), ("J", 7, 4, 11), ("K", 9, 1, 25)],
    "Job2": [("L", 3, 1, 29), ("M", 7, 1, 14), ("N", 1, 4, 20), ("O", 11, 3, 21), ("P", 10, 3, 16), ("Q", 4, 2, 11), ("R", 2, 1, 18), ("S", 6, 2, 28), ("T", 8, 3, 30), ("U", 9, 1, 21), ("V", 5, 4, 11)],
    "Job3": [("W", 10, 4, 19), ("X", 1, 2, 15), ("Y", 6, 2, 26), ("Z", 5, 3, 21), ("AA", 4, 4, 26), ("AB", 3, 1, 29), ("AC", 11, 3, 30), ("AD", 8, 1, 23), ("AE", 2, 3, 22), ("AF", 7, 4, 29), ("AG", 9, 3, 22)],
    "Job4": [("AH", 9, 4, 20), ("AI", 11, 2, 16), ("AJ", 2, 2, 25), ("AK", 4, 3, 14), ("AL", 3, 1, 27), ("AM", 1, 2, 22), ("AN", 8, 2, 26), ("AO", 7, 2, 27), ("AP", 5, 3, 25), ("AQ", 6, 2, 25), ("AR", 10, 1, 24)],
    "Job5": [("AS", 9, 4, 25), ("AT", 3, 2, 16), ("AU", 5, 2, 18), ("AV", 8, 3, 27), ("AW", 7, 2, 20), ("AX", 1, 4, 27), ("AY", 4, 2, 20), ("AZ", 2, 2, 28), ("BA", 6, 2, 11), ("BB", 10, 4, 19), ("BC", 11, 2, 16)],
    "Job6": [("BD", 3, 2, 23), ("BE", 2, 2, 27), ("BF", 9, 4, 12), ("BG", 8, 3, 30), ("BH", 5, 2, 10), ("BI", 10, 4, 22), ("BJ", 1, 1, 20), ("BK", 7, 2, 18), ("BL", 4, 3, 20), ("BM", 6, 2, 20), ("BN", 11, 3, 21)],
    "Job7": [("BO", 4, 1, 28), ("BP", 7, 3, 12), ("BQ", 10, 3, 16), ("BR", 11, 1, 20), ("BS", 2, 4, 15), ("BT", 6, 1, 29), ("BU", 8, 2, 28), ("BV", 9, 2, 21), ("BW", 5, 4, 18), ("BX", 1, 2, 11), ("BY", 3, 4, 25)],
    "Job8": [("BZ", 8, 2, 30), ("CA", 3, 3, 12), ("CB", 4, 2, 11), ("CC", 7, 4, 22), ("CD", 9, 3, 11), ("CE", 2, 3, 24), ("CF", 11, 3, 13), ("CG", 5, 3, 27), ("CH", 10, 4, 27), ("CI", 1, 3, 24), ("CJ", 6, 2, 23)],
    "Job9": [("CK", 4, 1, 10), ("CL", 9, 2, 19), ("CM", 2, 4, 23), ("CN", 10, 4, 13), ("CO", 5, 2, 22), ("CP", 3, 1, 12), ("CQ", 7, 1, 20), ("CR", 6, 3, 38), ("CS", 8, 4, 25), ("CT", 11, 4, 30), ("CU", 1, 4, 24)],
    "Job10": [("CV", 3, 2, 30), ("CW", 10, 2, 15), ("CX", 2, 1, 11), ("CY", 8, 2, 19), ("CZ", 5, 4, 29), ("DA", 11, 4, 12), ("DB", 4, 3, 27), ("DC", 7, 2, 26), ("DD", 6, 2, 22), ("DE", 9, 4, 24), ("DF", 1, 3, 10)],
    "Job11": [("DG", 11, 3, 15), ("DH", 6, 1, 22), ("DI", 3, 1, 28), ("DJ", 2, 2, 20), ("DK", 9, 4, 29), ("DL", 4, 3, 14), ("DM", 1, 1, 13), ("DN", 8, 3, 19), ("DO", 7, 1, 28), ("DP", 10, 4, 30), ("DQ", 5, 1, 11)]
}

# %% [markdown]
# # Data in format for MILP
# prec = Preceding task
# dur = duration

# %%
TASKS = {
('Job1', 'Machine8'): {'dur': 2, 'prec': None},
('Job1', 'Machine6'): {'dur': 2, 'prec': ('Job1', 'Machine8')},
('Job1', 'Machine10'): {'dur': 2, 'prec': ('Job1', 'Machine6')},
('Job1', 'Machine1'): {'dur': 1, 'prec': ('Job1', 'Machine10')},
('Job1', 'Machine11'): {'dur': 3, 'prec': ('Job1', 'Machine1')},
('Job1', 'Machine5'): {'dur': 4, 'prec': ('Job1', 'Machine11')},
('Job1', 'Machine2'): {'dur': 1, 'prec': ('Job1', 'Machine5')},
('Job1', 'Machine4'): {'dur': 1, 'prec': ('Job1', 'Machine2')},
('Job1', 'Machine3'): {'dur': 1, 'prec': ('Job1', 'Machine4')},
('Job1', 'Machine7'): {'dur': 4, 'prec': ('Job1', 'Machine3')},
('Job1', 'Machine9'): {'dur': 1, 'prec': ('Job1', 'Machine7')},
('Job2', 'Machine3'): {'dur': 1, 'prec': None},
('Job2', 'Machine7'): {'dur': 1, 'prec': ('Job2', 'Machine3')},
('Job2', 'Machine1'): {'dur': 4, 'prec': ('Job2', 'Machine7')},
('Job2', 'Machine11'): {'dur': 3, 'prec': ('Job2', 'Machine1')},
('Job2', 'Machine10'): {'dur': 3, 'prec': ('Job2', 'Machine11')},
('Job2', 'Machine4'): {'dur': 2, 'prec': ('Job2', 'Machine10')},
('Job2', 'Machine2'): {'dur': 1, 'prec': ('Job2', 'Machine4')},
('Job2', 'Machine6'): {'dur': 2, 'prec': ('Job2', 'Machine2')},
('Job2', 'Machine8'): {'dur': 3, 'prec': ('Job2', 'Machine6')},
('Job2', 'Machine9'): {'dur': 1, 'prec': ('Job2', 'Machine8')},
('Job2', 'Machine5'): {'dur': 4, 'prec': ('Job2', 'Machine9')},
('Job3', 'Machine10'): {'dur': 4, 'prec': None},
('Job3', 'Machine1'): {'dur': 2, 'prec': ('Job3', 'Machine10')},
('Job3', 'Machine6'): {'dur': 2, 'prec': ('Job3', 'Machine1')},
('Job3', 'Machine5'): {'dur': 3, 'prec': ('Job3', 'Machine6')},
('Job3', 'Machine4'): {'dur': 4, 'prec': ('Job3', 'Machine5')},
('Job3', 'Machine3'): {'dur': 1, 'prec': ('Job3', 'Machine4')},
('Job3', 'Machine11'): {'dur': 3, 'prec': ('Job3', 'Machine3')},
('Job3', 'Machine8'): {'dur': 1, 'prec': ('Job3', 'Machine11')},
('Job3', 'Machine2'): {'dur': 3, 'prec': ('Job3', 'Machine8')},
('Job3', 'Machine7'): {'dur': 4, 'prec': ('Job3', 'Machine2')},
('Job3', 'Machine9'): {'dur': 3, 'prec': ('Job3', 'Machine7')},
('Job4', 'Machine9'): {'dur': 4, 'prec': None},
('Job4', 'Machine11'): {'dur': 2, 'prec': ('Job4', 'Machine9')},
('Job4', 'Machine2'): {'dur': 2, 'prec': ('Job4', 'Machine11')},
('Job4', 'Machine4'): {'dur': 3, 'prec': ('Job4', 'Machine2')},
('Job4', 'Machine3'): {'dur': 1, 'prec': ('Job4', 'Machine4')},
('Job4', 'Machine1'): {'dur': 2, 'prec': ('Job4', 'Machine3')},
('Job4', 'Machine8'): {'dur': 2, 'prec': ('Job4', 'Machine1')},
('Job4', 'Machine7'): {'dur': 2, 'prec': ('Job4', 'Machine8')},
('Job4', 'Machine5'): {'dur': 3, 'prec': ('Job4', 'Machine7')},
('Job4', 'Machine6'): {'dur': 2, 'prec': ('Job4', 'Machine5')},
('Job4', 'Machine10'): {'dur': 1, 'prec': ('Job4', 'Machine6')},
('Job5', 'Machine9'): {'dur': 4, 'prec': None},
('Job5', 'Machine3'): {'dur': 2, 'prec': ('Job5', 'Machine9')},
('Job5', 'Machine5'): {'dur': 2, 'prec': ('Job5', 'Machine3')},
('Job5', 'Machine8'): {'dur': 3, 'prec': ('Job5', 'Machine5')},
('Job5', 'Machine7'): {'dur': 2, 'prec': ('Job5', 'Machine8')},
('Job5', 'Machine1'): {'dur': 4, 'prec': ('Job5', 'Machine7')},
('Job5', 'Machine4'): {'dur': 2, 'prec': ('Job5', 'Machine1')},
('Job5', 'Machine2'): {'dur': 2, 'prec': ('Job5', 'Machine4')},
('Job5', 'Machine6'): {'dur': 2, 'prec': ('Job5', 'Machine2')},
('Job5', 'Machine10'): {'dur': 4, 'prec': ('Job5', 'Machine6')},
('Job5', 'Machine11'): {'dur': 2, 'prec': ('Job5', 'Machine10')},
('Job6', 'Machine3'): {'dur': 2, 'prec': None},
('Job6', 'Machine2'): {'dur': 2, 'prec': ('Job6', 'Machine3')},
('Job6', 'Machine9'): {'dur': 4, 'prec': ('Job6', 'Machine2')},
('Job6', 'Machine8'): {'dur': 3, 'prec': ('Job6', 'Machine9')},
('Job6', 'Machine5'): {'dur': 2, 'prec': ('Job6', 'Machine8')},
('Job6', 'Machine10'): {'dur': 4, 'prec': ('Job6', 'Machine5')},
('Job6', 'Machine1'): {'dur': 1, 'prec': ('Job6', 'Machine10')},
('Job6', 'Machine7'): {'dur': 2, 'prec': ('Job6', 'Machine1')},
('Job6', 'Machine4'): {'dur': 3, 'prec': ('Job6', 'Machine7')},
('Job6', 'Machine6'): {'dur': 2, 'prec': ('Job6', 'Machine4')},
('Job6', 'Machine11'): {'dur': 3, 'prec': ('Job6', 'Machine6')},
('Job7', 'Machine4'): {'dur': 1, 'prec': None},
('Job7', 'Machine7'): {'dur': 3, 'prec': ('Job7', 'Machine4')},
('Job7', 'Machine10'): {'dur': 3, 'prec': ('Job7', 'Machine7')},
('Job7', 'Machine11'): {'dur': 1, 'prec': ('Job7', 'Machine10')},
('Job7', 'Machine2'): {'dur': 4, 'prec': ('Job7', 'Machine11')},
('Job7', 'Machine6'): {'dur': 1, 'prec': ('Job7', 'Machine2')},
('Job7', 'Machine8'): {'dur': 2, 'prec': ('Job7', 'Machine6')},
('Job7', 'Machine9'): {'dur': 2, 'prec': ('Job7', 'Machine8')},
('Job7', 'Machine5'): {'dur': 4, 'prec': ('Job7', 'Machine9')},
('Job7', 'Machine1'): {'dur': 2, 'prec': ('Job7', 'Machine5')},
('Job7', 'Machine3'): {'dur': 4, 'prec': ('Job7', 'Machine1')},
('Job8', 'Machine8'): {'dur': 2, 'prec': None},
('Job8', 'Machine3'): {'dur': 3, 'prec': ('Job8', 'Machine8')},
('Job8', 'Machine4'): {'dur': 2, 'prec': ('Job8', 'Machine3')},
('Job8', 'Machine7'): {'dur': 4, 'prec': ('Job8', 'Machine4')},
('Job8', 'Machine9'): {'dur': 3, 'prec': ('Job8', 'Machine7')},
('Job8', 'Machine2'): {'dur': 3, 'prec': ('Job8', 'Machine9')},
('Job8', 'Machine11'): {'dur': 3, 'prec': ('Job8', 'Machine2')},
('Job8', 'Machine5'): {'dur': 3, 'prec': ('Job8', 'Machine11')},
('Job8', 'Machine10'): {'dur': 4, 'prec': ('Job8', 'Machine5')},
('Job8', 'Machine1'): {'dur': 3, 'prec': ('Job8', 'Machine10')},
('Job8', 'Machine6'): {'dur': 2, 'prec': ('Job8', 'Machine1')},
('Job9', 'Machine4'): {'dur': 1, 'prec': None},
('Job9', 'Machine9'): {'dur': 2, 'prec': ('Job9', 'Machine4')},
('Job9', 'Machine2'): {'dur': 4, 'prec': ('Job9', 'Machine9')},
('Job9', 'Machine10'): {'dur': 4, 'prec': ('Job9', 'Machine2')},
('Job9', 'Machine5'): {'dur': 2, 'prec': ('Job9', 'Machine10')},
('Job9', 'Machine3'): {'dur': 1, 'prec': ('Job9', 'Machine5')},
('Job9', 'Machine7'): {'dur': 1, 'prec': ('Job9', 'Machine3')},
('Job9', 'Machine6'): {'dur': 3, 'prec': ('Job9', 'Machine7')},
('Job9', 'Machine8'): {'dur': 4, 'prec': ('Job9', 'Machine6')},
('Job9', 'Machine11'): {'dur': 4, 'prec': ('Job9', 'Machine8')},
('Job9', 'Machine1'): {'dur': 4, 'prec': ('Job9', 'Machine11')},
('Job10', 'Machine3'): {'dur': 2, 'prec': None},
('Job10', 'Machine10'): {'dur': 2, 'prec': ('Job10', 'Machine3')},
('Job10', 'Machine2'): {'dur': 1, 'prec': ('Job10', 'Machine10')},
('Job10', 'Machine8'): {'dur': 2, 'prec': ('Job10', 'Machine2')},
('Job10', 'Machine5'): {'dur': 4, 'prec': ('Job10', 'Machine8')},
('Job10', 'Machine11'): {'dur': 4, 'prec': ('Job10', 'Machine5')},
('Job10', 'Machine4'): {'dur': 3, 'prec': ('Job10', 'Machine11')},
('Job10', 'Machine7'): {'dur': 2, 'prec': ('Job10', 'Machine4')},
('Job10', 'Machine6'): {'dur': 2, 'prec': ('Job10', 'Machine7')},
('Job10', 'Machine9'): {'dur': 4, 'prec': ('Job10', 'Machine6')},
('Job10', 'Machine1'): {'dur': 3, 'prec': ('Job10', 'Machine9')},
('Job11', 'Machine11'): {'dur': 3, 'prec': None},
('Job11', 'Machine6'): {'dur': 1, 'prec': ('Job11', 'Machine11')},
('Job11', 'Machine3'): {'dur': 1, 'prec': ('Job11', 'Machine6')},
('Job11', 'Machine2'): {'dur': 2, 'prec': ('Job11', 'Machine3')},
('Job11', 'Machine9'): {'dur': 4, 'prec': ('Job11', 'Machine2')},
('Job11', 'Machine4'): {'dur': 3, 'prec': ('Job11', 'Machine9')},
('Job11', 'Machine1'): {'dur': 1, 'prec': ('Job11', 'Machine4')},
('Job11', 'Machine8'): {'dur': 3, 'prec': ('Job11', 'Machine1')},
('Job11', 'Machine7'): {'dur': 1, 'prec': ('Job11', 'Machine8')},
('Job11', 'Machine10'): {'dur': 4, 'prec': ('Job11', 'Machine7')},
('Job11', 'Machine5'): {'dur': 1, 'prec': ('Job11', 'Machine10')},
}
energy_rates = {
    
    ('Job1', 'Machine8'): 26,
 ('Job1', 'Machine6'): 21,
 ('Job1', 'Machine10'): 24,
 ('Job1', 'Machine1'): 10,
 ('Job1', 'Machine11'): 20,
 ('Job1', 'Machine5'): 16,
 ('Job1', 'Machine2'): 20,
 ('Job1', 'Machine4'): 12,
 ('Job1', 'Machine3'): 23,
 ('Job1', 'Machine7'): 11,
 ('Job1', 'Machine9'): 25,
 ('Job2', 'Machine3'): 29,
 ('Job2', 'Machine7'): 14,
 ('Job2', 'Machine1'): 20,
 ('Job2', 'Machine11'): 21,
 ('Job2', 'Machine10'): 16,
 ('Job2', 'Machine4'): 11,
 ('Job2', 'Machine2'): 18,
 ('Job2', 'Machine6'): 28,
 ('Job2', 'Machine8'): 30,
 ('Job2', 'Machine9'): 21,
 ('Job2', 'Machine5'): 11,
 ('Job3', 'Machine10'): 19,
 ('Job3', 'Machine1'): 15,
 ('Job3', 'Machine6'): 26,
 ('Job3', 'Machine5'): 21,
 ('Job3', 'Machine4'): 26,
 ('Job3', 'Machine3'): 29,
 ('Job3', 'Machine11'): 30,
 ('Job3', 'Machine8'): 23,
 ('Job3', 'Machine2'): 22,
 ('Job3', 'Machine7'): 29,
 ('Job3', 'Machine9'): 22,
 ('Job4', 'Machine9'): 20,
 ('Job4', 'Machine11'): 16,
 ('Job4', 'Machine2'): 25,
 ('Job4', 'Machine4'): 14,
 ('Job4', 'Machine3'): 27,
 ('Job4', 'Machine1'): 22,
 ('Job4', 'Machine8'): 26,
 ('Job4', 'Machine7'): 27,
 ('Job4', 'Machine5'): 25,
 ('Job4', 'Machine6'): 25,
 ('Job4', 'Machine10'): 24,
 ('Job5', 'Machine9'): 25,
 ('Job5', 'Machine3'): 16,
 ('Job5', 'Machine5'): 18,
 ('Job5', 'Machine8'): 27,
 ('Job5', 'Machine7'): 20,
 ('Job5', 'Machine1'): 27,
 ('Job5', 'Machine4'): 20,
 ('Job5', 'Machine2'): 28,
 ('Job5', 'Machine6'): 11,
 ('Job5', 'Machine10'): 19,
 ('Job5', 'Machine11'): 16,
 ('Job6', 'Machine3'): 23,
 ('Job6', 'Machine2'): 27,
 ('Job6', 'Machine9'): 12,
 ('Job6', 'Machine8'): 30,
 ('Job6', 'Machine5'): 10,
 ('Job6', 'Machine10'): 22,
 ('Job6', 'Machine1'): 20,
 ('Job6', 'Machine7'): 18,
 ('Job6', 'Machine4'): 20,
 ('Job6', 'Machine6'): 20,
 ('Job6', 'Machine11'): 21,
 ('Job7', 'Machine4'): 28,
 ('Job7', 'Machine7'): 12,
 ('Job7', 'Machine10'): 16,
 ('Job7', 'Machine11'): 20,
 ('Job7', 'Machine2'): 15,
 ('Job7', 'Machine6'): 29,
 ('Job7', 'Machine8'): 28,
 ('Job7', 'Machine9'): 21,
 ('Job7', 'Machine5'): 18,
 ('Job7', 'Machine1'): 11,
 ('Job7', 'Machine3'): 25,
 ('Job8', 'Machine8'): 30,
 ('Job8', 'Machine3'): 12,
 ('Job8', 'Machine4'): 11,
 ('Job8', 'Machine7'): 22,
 ('Job8', 'Machine9'): 11,
 ('Job8', 'Machine2'): 24,
 ('Job8', 'Machine11'): 13,
 ('Job8', 'Machine5'): 27,
 ('Job8', 'Machine10'): 27,
 ('Job8', 'Machine1'): 24,
 ('Job8', 'Machine6'): 23,
 ('Job9', 'Machine4'): 10,
 ('Job9', 'Machine9'): 19,
 ('Job9', 'Machine2'): 23,
 ('Job9', 'Machine10'): 13,
 ('Job9', 'Machine5'): 22,
 ('Job9', 'Machine3'): 12,
 ('Job9', 'Machine7'): 20,
 ('Job9', 'Machine6'): 38,
 ('Job9', 'Machine8'): 25,
 ('Job9', 'Machine11'): 30,
 ('Job9', 'Machine1'): 24,
 ('Job10', 'Machine3'): 30,
 ('Job10', 'Machine10'): 15,
 ('Job10', 'Machine2'): 11,
 ('Job10', 'Machine8'): 19,
 ('Job10', 'Machine5'): 29,
 ('Job10', 'Machine11'): 12,
 ('Job10', 'Machine4'): 27,
 ('Job10', 'Machine7'): 26,
 ('Job10', 'Machine6'): 22,
 ('Job10', 'Machine9'): 24,
 ('Job10', 'Machine1'): 10,
 ('Job11', 'Machine11'): 15,
 ('Job11', 'Machine6'): 22,
 ('Job11', 'Machine3'): 28,
 ('Job11', 'Machine2'): 20,
 ('Job11', 'Machine9'): 29,
 ('Job11', 'Machine4'): 14,
 ('Job11', 'Machine1'): 13,
 ('Job11', 'Machine8'): 19,
 ('Job11', 'Machine7'): 28,
 ('Job11', 'Machine10'): 30,
 ('Job11', 'Machine5'): 11
}
